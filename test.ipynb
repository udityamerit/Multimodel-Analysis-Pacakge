# %%
import pandas as pd
from multimodel_analysis import MultiModelClassifier

df = pd.read_csv('https://raw.githubusercontent.com/udityamerit/MultiModel-Package-for-Machine-Learning/refs/heads/main/Dataset/diabetes.csv')
X = df.drop('Outcome', axis=1)
y = df['Outcome']

# %%
model = MultiModelClassifier(X, y, test_size=0.3, scaled_data=True) # it is for calling your classifier model
models = model.run_all_models()

# %%
# model.show_tabular_report(models)

# %%
# model.plot_confusion_matrices(models)

# %%
model.get_summary(models)
# Out:
# ...
#  📊 MODEL COMPARISON TABLE
# ...
#                  Model  Accuracy  Precision    Recall  F1 Score   ROC AUC
# 0        Random Forest  0.757576   0.759069  0.757576  0.758264  0.804636
# 1             AdaBoost  0.753247   0.751223  0.753247  0.752103  0.821358
# 2                  SVM  0.748918   0.747507  0.748918  0.748155  0.803063
# 3          Naive Bayes  0.744589   0.748735  0.744589  0.746309  0.790480
# 4    Gradient Boosting  0.744589   0.746982  0.744589  0.745658  0.791970
# 5  Logistic Regression  0.735931   0.736722  0.735931  0.736312  0.798013
# 6        Decision Tree  0.718615   0.734019  0.718615  0.723321  0.711300
# 7                  KNN  0.696970   0.684580  0.696970  0.686286  0.748386
# ...
#
# ⭐ BEST MODEL RECOMMENDATION: Random Forest
#    Accuracy: 0.7576 | F1 Score: 0.7583
# ...

# %%
# model.plot_confusion_matrices(models)

# %%
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/udityamerit/Complete-Machine-Learning-For-Beginners/refs/heads/main/0-Dataset/Algerian_forest_fires_dataset_cleaned.csv')

# %%
df.drop(['day', 'month', 'year'], axis=1, inplace=True)

df['Classes'] = np.where(df['Classes'].str.contains('not fire'), 0, 1) ## here 1 denotes the else part

# %%
## Independent and dependent features
X =df.drop('FWI', axis=1)
y = df['FWI']

# %%
from multimodel_analysis import MultiModelRegressior
reg_model = MultiModelRegressior(X, y, test_size=0.5, scaled_data=True)
mode = reg_model.run_all_models()

# %%
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0     0.0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0     0.0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0     0.0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0     0.0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0     0.0

# %%
reg_model.plot_true_vs_predicted(mode)

# %%
reg_model.show_tabular_report(mode)
# Out:
# ...
#  📊 REGRESSION MODEL COMPARISON TABLE
# ...
#                          Model       MAE        MSE      RMSE  R2 Score
# 0            Linear Regression  0.688003   0.943641  0.971412  0.982893
# 1             Ridge Regression  0.728731   1.044027  1.021776  0.981073
# 2             Lasso Regression  0.815481   1.239035  1.113120  0.977538
# 3  Gradient Boosting Regressor  0.687815   1.343918  1.159275  0.975637
# 4      Random Forest Regressor  0.765975   1.505321  1.226915  0.972711
# 5      Decision Tree Regressor  1.135246   3.060246  1.749356  0.944522
# 6                          SVR  1.870482  12.665432  3.558853  0.770392
# ...
#
# ⭐ BEST MODEL RECOMMENDATION: Linear Regression
#    R2 Score: 0.9829 | RMSE: 0.9714
# ...

# %%
reg_model.get_summary(mode)
# Out:
# ...
#  📊 REGRESSION MODEL COMPARISON TABLE
# ...
#                          Model       MAE        MSE      RMSE  R2 Score
# 0            Linear Regression  0.688003   0.943641  0.971412  0.982893
# 1             Ridge Regression  0.728731   1.044027  1.021776  0.981073
# 2             Lasso Regression  0.815481   1.239035  1.113120  0.977538
# 3  Gradient Boosting Regressor  0.687815   1.343918  1.159275  0.975637
# 4      Random Forest Regressor  0.765975   1.505321  1.226915  0.972711
# 5      Decision Tree Regressor  1.135246   3.060246  1.749356  0.944522
# 6                          SVR  1.870482  12.665432  3.558853  0.770392
# ...
#
# ⭐ BEST MODEL RECOMMENDATION: Linear Regression
#    R2 Score: 0.9829 | RMSE: 0.9714
# ...
